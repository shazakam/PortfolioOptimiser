# %%
import pandas as pd 

df = pd.read_csv(r'data/Euronext_Equities_2025-08-19.csv', sep = ';')

# %%
df['Market'].dropna().unique()
# Out:
# array(['Oslo Børs', 'Euronext Growth Paris', 'EuroTLX',
#        'Euronext Global Equity Market', 'Trading After Hours',
#        'Euronext Growth Milan', 'Euronext Expand Oslo', 'Euronext Paris',
#        'Euronext Milan', 'Euronext Amsterdam', 'Euronext Growth Oslo',
#        'Euronext Brussels', 'Euronext Expert Market',
#        'Euronext Brussels, Paris', 'Euronext Access Paris',
#        'Euronext Access Brussels', 'Euronext Brussels, Amsterdam',
#        'Euronext Amsterdam, Brussels', 'Euronext Dublin',
#        'Euronext Paris, Amsterdam', 'Euronext Lisbon',
#        'Euronext Amsterdam, Brussels, Paris', 'Euronext Growth Dublin',
#        'Euronext Amsterdam, Paris', 'Euronext Access Lisbon',
#        'Euronext Growth Brussels', 'Euronext Paris, Brussels',
#        'Euronext Paris, Amsterdam, Brussels',
#        'Euronext Growth Brussels, Paris',
#        'Euronext Growth Paris, Brussels',
#        'Euronext Brussels, Amsterdam, Paris', 'Euronext Growth Lisbon'],
# ...

# %%
import yfinance as yf
data = yf.Ticker('DNB.OL')

# %%
import plotly.express as px
pd.DataFrame(data.income_stmt.loc['Diluted EPS'])
# Out:
#             Diluted EPS
# 2024-12-31        29.34
# 2023-12-31        24.83
# 2022-12-31        21.02
# 2021-12-31        15.74
# 2020-12-31          NaN

# %%
data.cash_flow
# Out:
#                                                     2024-12-31    2023-12-31  \
# Free Cash Flow                                   -1.591210e+11  4.300000e+07
# Repurchase Of Capital Stock                      -7.101000e+09 -6.916000e+09
# Repayment Of Debt                                -7.141000e+09 -1.011000e+10
# Issuance Of Debt                                  1.319700e+10  4.647300e+10
# Issuance Of Capital Stock                                  NaN           NaN
# Capital Expenditure                              -2.677000e+09 -4.081000e+09
# End Cash Position                                 1.522400e+11  3.355800e+11
# Other Cash Adjustment Outside Changein Cash                NaN           NaN
# Beginning Cash Position                           3.355800e+11  3.171230e+11
# Effect Of Exchange Rate Changes                   3.559000e+09  1.913000e+09
# Changes In Cash                                  -1.868990e+11  1.654400e+10
# ...

# %%
data.balance_sheet
# Out:
#                                                 2024-12-31    2023-12-31  \
# Treasury Shares Number                        9.850699e+06  2.577472e+07
# Ordinary Shares Number                        1.482680e+09  1.516838e+09
# Share Issued                                  1.492530e+09  1.542613e+09
# Net Debt                                      8.643060e+11  6.187960e+11
# Total Debt                                    1.014425e+12  9.523670e+11
# ...                                                    ...           ...
# Notes Receivable                                       NaN  1.253000e+09
# Other Short Term Investments                           NaN  1.945440e+11
# Cash And Cash Equivalents                     1.479440e+11  3.314080e+11
# Cash Financial                                         NaN           NaN
# Cash Cash Equivalents And Federal Funds Sold  1.479440e+11  3.314080e+11
#
#                                                 2022-12-31    2021-12-31  \
# ...

# %%
data.balance_sheet.loc['Stockholders Equity'] / (data.balance_sheet.loc['Total Assets'] - data.balance_sheet.loc['Total Liabilities Net Minority Interest'])
# Out:
# 2024-12-31    0.999231
# 2023-12-31    0.999376
# 2022-12-31    0.999091
# 2021-12-31    0.998909
# 2020-12-31         NaN
# dtype: float64

# %%
data.info['priceToBook']
# Out:
# 1.5796314

# %%
data.balance_sheet.loc['Stockholders Equity']
# Out:
# 2024-12-31    151800000.0
# 2023-12-31    161000000.0
# 2022-12-31    155900000.0
# 2021-12-31    151700000.0
# 2020-12-31            NaN
# Name: Stockholders Equity, dtype: float64

# %%
data.income_stmt
# Out:
#                                                       2024-12-31  \
# Tax Effect Of Unusual Items                         3.718182e+05
# Tax Rate For Calcs                                  9.091000e-03
# Normalized EBITDA                                   5.240000e+07
# Total Unusual Items                                 4.090000e+07
# Total Unusual Items Excluding Goodwill              4.090000e+07
# Net Income From Continuing Operation Net Minori...  7.630000e+07
# Reconciled Depreciation                             9.500000e+06
# Reconciled Cost Of Revenue                          2.650000e+07
# EBITDA                                              9.330000e+07
# EBIT                                                8.380000e+07
# Net Interest Income                                -6.700000e+06
# Interest Expense                                    6.800000e+06
# Interest Income                                     1.000000e+05
# ...

# %%
year_av = []
df = data.history(period="10y")
df.index = df.index.tz_localize(None)

for end_date in list(data.incomestmt.loc['Diluted EPS'].index):
    start_date = end_date - pd.DateOffset(years=1)
    average = df.loc[start_date:end_date]['Close'].mean()
    year_av.append(float(average))

# %%
data.info['trailingPE']
# Out:
# 13.778005

# %%
data.incomestmt.loc['Diluted EPS'].dropna()
# Out:
# 2024-12-31    3.34
# 2023-12-31    1.13
# 2022-12-31    1.42
# 2021-12-31    3.14
# Name: Diluted EPS, dtype: float64

# %%
year_av.reverse()

# %%
year_av
# Out:
# [96.77774839552622, 101.5785928959903, 99.36319723547217, 143.8657020263672]

# %%
hist_data = data.history(period="10y")
hist_data.index = hist_data.index.tz_localize(None)

# %%
hist_data
# Out:
#                   Open        High         Low       Close  Volume  Dividends  \
# Date
# 2019-07-12   79.637098   82.194255   75.801369   75.801369   40831        0.0
# 2019-07-15   75.801370   76.696377   73.974831   73.974831    8810        0.0
# 2019-07-16   73.974831   73.974831   73.061561   73.974831   21400        0.0
# 2019-07-17   73.974831   73.974831   73.527331   73.974831   12966        0.0
# 2019-07-18   73.070696   73.070696   70.330888   73.061562    4789        0.0
# ...                ...         ...         ...         ...     ...        ...
# 2025-09-29  143.699997  143.800003  135.600006  135.600006  413393        0.0
# 2025-09-30  135.399994  136.199997  133.600006  134.300003  255819        0.0
# 2025-10-01  134.300003  135.199997  133.100006  134.000000  199156        0.0
# 2025-10-02  136.800003  138.699997  135.699997  137.199997  161770        0.0
# 2025-10-03  138.600006  138.600006  134.500000  135.300003  128323        0.0
#
#             Stock Splits
# ...

# %%
t1 = data.incomestmt.loc['Diluted EPS'].index[-1] - pd.DateOffset(years=1)
hist_data.loc[t1:data.incomestmt.loc['Diluted EPS'].index[-1]]['Close'].mean()
# Out:
# np.float64(96.7777450046842)

# %%
hist_data.index[0]
# Out:
# Timestamp('2019-07-12 00:00:00')

# %%
hist_data
# Out:
#                   Open        High         Low       Close  Volume  Dividends  \
# Date
# 2019-07-12   79.637098   82.194255   75.801369   75.801369   40831        0.0
# 2019-07-15   75.801370   76.696377   73.974831   73.974831    8810        0.0
# 2019-07-16   73.974831   73.974831   73.061561   73.974831   21400        0.0
# 2019-07-17   73.974831   73.974831   73.527331   73.974831   12966        0.0
# 2019-07-18   73.070696   73.070696   70.330888   73.061562    4789        0.0
# ...                ...         ...         ...         ...     ...        ...
# 2025-09-29  143.699997  143.800003  135.600006  135.600006  413393        0.0
# 2025-09-30  135.399994  136.199997  133.600006  134.300003  255819        0.0
# 2025-10-01  134.300003  135.199997  133.100006  134.000000  199156        0.0
# 2025-10-02  136.800003  138.699997  135.699997  137.199997  161770        0.0
# 2025-10-03  138.600006  138.600006  134.500000  135.300003  128323        0.0
#
#             Stock Splits
# ...
