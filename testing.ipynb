# %%
import streamlit as st 
import pandas as pd
import yfinance as yf
from utils.data_utils import load_market_data
import jax.numpy as jnp
from utils.volatility_calculator import VolatilityCalculator

def get_equity_list() -> pd.DataFrame:
    df = pd.read_csv(
            "data/Euronext_Equities_2025-08-19.csv",
            sep=";",          # Euronext uses semicolons
            skiprows=0,       # adjust if file has metadata rows
            on_bad_lines="skip"  # skip problematic rows if any
        )
    return df

# %%
market_df = get_equity_list()
yf_market_tag_index = {
    'Oslo Børs': ['OL', 'OSEBX.OL'],
    'Euronext Paris': ['PA', 'Yabadadoo.PA']}

# %%
possible_markets = ['Oslo Børs']
start_date = pd.to_datetime("2021-07-01")
end_date = pd.to_datetime("2025-05-27")

# %%
filtered_df = market_df[market_df['Market'].isin(possible_markets)]
market_grouped_equities = filtered_df.groupby('Market')

# %%
ticker_dictionary = {}
for market in possible_markets:
    tickers = market_grouped_equities.get_group(market)['Symbol'].tolist()
    tickers = [f"{ticker}.{yf_market_tag_index[market][0]}" for ticker in tickers]
    ticker_dictionary[market] = tickers

# %%
ticker_dictionary
# Out:
# {'Oslo Børs': ['2020.OL',
#   'ABG.OL',
#   'ABL.OL',
#   'AFG.OL',
#   'AGLX.OL',
#   'AIRX.OL',
#   'AKAST.OL',
#   'AKER.OL',
#   'AKBM.OL',
#   'AKRBP.OL',
#   'ACC.OL',
#   'AKH.OL',
#   'AKSO.OL',
#   'AKVA.OL',
#   'AMSC.OL',
#   'ARCH.OL',
#   'AZT.OL',
#   'AFK.OL',
#   'ARR.OL',
#   'ATEA.OL',
#   'ASAS.OL',
#   'ASA.OL',
#   'AURG.OL',
#   'AUSS.OL',
#   'AUTO.OL',
#   'AGAS.OL',
#   'ACR.OL',
#   'B2I.OL',
#   'BAKKA.OL',
#   'BGBIO.OL',
#   'BEWI.OL',
#   'BIEN.OL',
#   'BNOR.OL',
#   'BONHR.OL',
#   'BOR.OL',
#   'BRG.OL',
#   'BOUV.OL',
#   'BWE.OL',
#   'BWLPG.OL',
#   'BWO.OL',
#   'BMA.OL',
#   'CADLR.OL',
#   'CAPSL.OL',
#   'CAVEN.OL',
#   'CRNA.OL',
#   'CLOUD.OL',
#   'CMBTO.OL',
#   'CONTX.OL',
#   'DNB.OL',
#   'DNO.OL',
#   'DOFG.OL',
#   'EIOF.OL',
#   'EMGS.OL',
#   'ELK.OL',
#   'ELABS.OL',
#   'ELMRA.OL',
#   'ELO.OL',
#   'ENDUR.OL',
#   'ENSU.OL',
#   'ENTRA.OL',
#   'ENVIP.OL',
#   'EQNR.OL',
#   'EQVA.OL',
#   'EPR.OL',
#   'FLNG.OL',
#   'FRO.OL',
#   'GENT.OL',
#   'GJF.OL',
#   'GOGL.OL',
#   'GOD.OL',
#   'GSF.OL',
#   'GYL.OL',
#   'HAFNI.OL',
#   'HGSB.OL',
#   'HAVI.OL',
#   'HERMA.OL',
#   'HEX.OL',
#   'HPUR.OL',
#   'HSHP.OL',
#   'HBC.OL',
#   'HYPRO.OL',
#   'HAUTO.OL',
#   'HSPG.OL',
#   'IDEX.OL',
#   'IWS.OL',
#   'IOX.OL',
#   'ITERA.OL',
#   'JIN.OL',
#   'JAREN.OL',
#   'KID.OL',
#   'KIT.OL',
#   'KCC.OL',
#   'KMCP.OL',
#   'KOMPL.OL',
#   'KOA.OL',
#   'KOG.OL',
#   'LSG.OL',
#   'LIFE.OL',
#   'LINK.OL',
#   'MGN.OL',
#   'MEDI.OL',
#   'MELG.OL',
#   'MORLD.OL',
#   'MOBA.OL',
#   'MOWI.OL',
#   'MPCC.OL',
#   'MULTI.OL',
#   'NAPA.OL',
#   'NAVA.OL',
#   'NKR.OL',
#   'NEL.OL',
#   'NEXT.OL',
#   'NORBT.OL',
#   'NORCO.OL',
#   'NOM.OL',
#   'NOD.OL',
#   'NHY.OL',
#   'NSKOG.OL',
#   'NOL.OL',
#   'NAS.OL',
#   'NRC.OL',
#   'NYKD.OL',
#   'ODL.OL',
#   'ODF.OL',
#   'ODFB.OL',
#   'OTL.OL',
#   'OKEA.OL',
#   'OET.OL',
#   'OLT.OL',
#   'ORK.OL',
#   'OTEC.OL',
#   'OTOVO.OL',
#   'PEN.OL',
#   'PLSV.OL',
#   'PARB.OL',
#   'PCIB.OL',
#   'PSE.OL',
#   'PNOR.OL',
#   'PEXIP.OL',
#   'PHO.OL',
#   'POL.OL',
#   'PLT.OL',
#   'PRS.OL',
#   'PROT.OL',
#   'PUBLI.OL',
#   'QEC.OL',
#   'RANA.OL',
#   'REACH.OL',
#   'RECSI.OL',
#   'ROGS.OL',
#   'SDSD.OL',
#   'SAGA.OL',
#   'SALM.OL',
#   'SALME.OL',
#   'SATS.OL',
#   'SCANA.OL',
#   'SCATC.OL',
#   'SEA1.OL',
#   'ENH.OL',
#   'SBO.OL',
#   'SNTIA.OL',
#   'SHLF.OL',
#   'SKUE.OL',
#   'SMCRT.OL',
#   'SWON.OL',
#   'SOGN.OL',
#   'SOMA.OL',
#   'SOFF.OL',
#   'MING.OL',
#   'SB1NO.OL',
#   'MORG.OL',
#   'SBNOR.OL',
#   'SPOG.OL',
#   'SNOR.OL',
#   'SPOL.OL',
#   'HELG.OL',
#   'NONG.OL',
#   'RING.OL',
#   'SOAG.OL',
#   'SPIR.OL',
#   'SNI.OL',
#   'STB.OL',
#   'STRO.OL',
#   'SUBC.OL',
#   'TECH.OL',
#   'TEKNA.OL',
#   'TEL.OL',
#   'TGS.OL',
#   'TRMED.OL',
#   'TIETO.OL',
#   'TOM.OL',
#   'TRE.OL',
#   'TRSB.OL',
#   'VEI.OL',
#   'VENDA.OL',
#   'VENDB.OL',
#   'VISTN.OL',
#   'VVL.OL',
#   'VOW.OL',
#   'VAR.OL',
#   'WAWI.OL',
#   'WSTEP.OL',
#   'WWI.OL',
#   'WWIB.OL',
#   'YAR.OL',
#   'ZAL.OL',
#   'ZAP.OL',
#   'ZLNA.OL']}

# %%
k = load_market_data(possible_markets, ticker_dictionary, start_date, end_date)
# Out:
# $ASAS.OL: possibly delisted; no price data found  (1d 2021-07-01 00:00:00 -> 2025-05-28 00:00:00)
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# 2025-05-27 00:00:00+02:00
# 2025-05-28 00:00:00
# True
# False
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 k = load_market_data(possible_markets, ticker_dictionary, start_date, end_date)
#
# File ~/Desktop/Coding Projects/PortfolioOptimiser/utils/data_utils.py:17, in load_market_data(possible_markets, ticker_dictionary, start_date, end_date)
#      15 ticker_class = yf.Ticker(tick)
#      16 hist_data = ticker_class.history(start=start_date, end=end_date)
# ---> 17 print(hist_data.index[-1])
#      18 print(end_date)
#      19 print((pd.to_datetime(hist_data.index[0]).date() == pd.to_datetime(start_date).date()))
#
# File /opt/anaconda3/envs/PortfolioOptim/lib/python3.10/site-packages/pandas/core/indexes/base.py:5401, in Index.__getitem__(self, key)
#    5398 if is_integer(key) or is_float(key):
#    5399     # GH#44051 exclude bool, which would return a 2d ndarray
#    5400     key = com.cast_scalar_indexer(key)
# -> 5401     return getitem(key)
#    5403 if isinstance(key, slice):
#    5404     # This case is separated from the conditional above to avoid
#    5405     # pessimization com.is_bool_indexer and ndim checks.
#    5406     return self._getitem_slice(key)
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %%
k
# Out:
# {'Oslo Børs': []}
