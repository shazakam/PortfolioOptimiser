# %%
import streamlit as st 
import pandas as pd
import yfinance as yf
from utils.data_utils import load_market_data
import jax.numpy as jnp
from utils.volatility_calculator import VolatilityCalculator

def get_equity_list() -> pd.DataFrame:
    df = pd.read_csv(
            "data/Euronext_Equities_2025-08-19.csv",
            sep=";",          # Euronext uses semicolons
            skiprows=0,       # adjust if file has metadata rows
            on_bad_lines="skip"  # skip problematic rows if any
        )
    return df

# %%
market_df = get_equity_list()
yf_market_tag_index = {
    'Oslo Børs': ['OL', 'OSEBX.OL'],
    'Euronext Paris': ['PA', 'Yabadadoo.PA']}

# %%
possible_markets = ['Oslo Børs']
start_date = pd.to_datetime("2021-07-01")
end_date = pd.to_datetime("2025-05-27")

# %%
filtered_df = market_df[market_df['Market'].isin(possible_markets)]
market_grouped_equities = filtered_df.groupby('Market')

# %%
ticker_dictionary = {}
for market in possible_markets:
    tickers = market_grouped_equities.get_group(market)['Symbol'].tolist()
    tickers = [f"{ticker}.{yf_market_tag_index[market][0]}" for ticker in tickers]
    ticker_dictionary[market] = tickers

# %%
ticker_dictionary
# Out:
# {'Oslo Børs': ['2020.OL',
#   'ABG.OL',
#   'ABL.OL',
#   'AFG.OL',
#   'AGLX.OL',
#   'AIRX.OL',
#   'AKAST.OL',
#   'AKER.OL',
#   'AKBM.OL',
#   'AKRBP.OL',
#   'ACC.OL',
#   'AKH.OL',
#   'AKSO.OL',
#   'AKVA.OL',
#   'AMSC.OL',
#   'ARCH.OL',
#   'AZT.OL',
#   'AFK.OL',
#   'ARR.OL',
#   'ATEA.OL',
#   'ASAS.OL',
#   'ASA.OL',
#   'AURG.OL',
#   'AUSS.OL',
#   'AUTO.OL',
#   'AGAS.OL',
#   'ACR.OL',
#   'B2I.OL',
#   'BAKKA.OL',
#   'BGBIO.OL',
#   'BEWI.OL',
#   'BIEN.OL',
#   'BNOR.OL',
#   'BONHR.OL',
#   'BOR.OL',
#   'BRG.OL',
#   'BOUV.OL',
#   'BWE.OL',
#   'BWLPG.OL',
#   'BWO.OL',
#   'BMA.OL',
#   'CADLR.OL',
#   'CAPSL.OL',
#   'CAVEN.OL',
#   'CRNA.OL',
#   'CLOUD.OL',
#   'CMBTO.OL',
#   'CONTX.OL',
#   'DNB.OL',
#   'DNO.OL',
#   'DOFG.OL',
#   'EIOF.OL',
#   'EMGS.OL',
#   'ELK.OL',
#   'ELABS.OL',
#   'ELMRA.OL',
#   'ELO.OL',
#   'ENDUR.OL',
#   'ENSU.OL',
#   'ENTRA.OL',
#   'ENVIP.OL',
#   'EQNR.OL',
#   'EQVA.OL',
#   'EPR.OL',
#   'FLNG.OL',
#   'FRO.OL',
#   'GENT.OL',
#   'GJF.OL',
#   'GOGL.OL',
#   'GOD.OL',
#   'GSF.OL',
#   'GYL.OL',
#   'HAFNI.OL',
#   'HGSB.OL',
#   'HAVI.OL',
#   'HERMA.OL',
#   'HEX.OL',
#   'HPUR.OL',
#   'HSHP.OL',
#   'HBC.OL',
#   'HYPRO.OL',
#   'HAUTO.OL',
#   'HSPG.OL',
#   'IDEX.OL',
#   'IWS.OL',
#   'IOX.OL',
#   'ITERA.OL',
#   'JIN.OL',
#   'JAREN.OL',
#   'KID.OL',
#   'KIT.OL',
#   'KCC.OL',
#   'KMCP.OL',
#   'KOMPL.OL',
#   'KOA.OL',
#   'KOG.OL',
#   'LSG.OL',
#   'LIFE.OL',
#   'LINK.OL',
#   'MGN.OL',
#   'MEDI.OL',
#   'MELG.OL',
#   'MORLD.OL',
#   'MOBA.OL',
#   'MOWI.OL',
#   'MPCC.OL',
#   'MULTI.OL',
#   'NAPA.OL',
#   'NAVA.OL',
#   'NKR.OL',
#   'NEL.OL',
#   'NEXT.OL',
#   'NORBT.OL',
#   'NORCO.OL',
#   'NOM.OL',
#   'NOD.OL',
#   'NHY.OL',
#   'NSKOG.OL',
#   'NOL.OL',
#   'NAS.OL',
#   'NRC.OL',
#   'NYKD.OL',
#   'ODL.OL',
#   'ODF.OL',
#   'ODFB.OL',
#   'OTL.OL',
#   'OKEA.OL',
#   'OET.OL',
#   'OLT.OL',
#   'ORK.OL',
#   'OTEC.OL',
#   'OTOVO.OL',
#   'PEN.OL',
#   'PLSV.OL',
#   'PARB.OL',
#   'PCIB.OL',
#   'PSE.OL',
#   'PNOR.OL',
#   'PEXIP.OL',
#   'PHO.OL',
#   'POL.OL',
#   'PLT.OL',
#   'PRS.OL',
#   'PROT.OL',
#   'PUBLI.OL',
#   'QEC.OL',
#   'RANA.OL',
#   'REACH.OL',
#   'RECSI.OL',
#   'ROGS.OL',
#   'SDSD.OL',
#   'SAGA.OL',
#   'SALM.OL',
#   'SALME.OL',
#   'SATS.OL',
#   'SCANA.OL',
#   'SCATC.OL',
#   'SEA1.OL',
#   'ENH.OL',
#   'SBO.OL',
#   'SNTIA.OL',
#   'SHLF.OL',
#   'SKUE.OL',
#   'SMCRT.OL',
#   'SWON.OL',
#   'SOGN.OL',
#   'SOMA.OL',
#   'SOFF.OL',
#   'MING.OL',
#   'SB1NO.OL',
#   'MORG.OL',
#   'SBNOR.OL',
#   'SPOG.OL',
#   'SNOR.OL',
#   'SPOL.OL',
#   'HELG.OL',
#   'NONG.OL',
#   'RING.OL',
#   'SOAG.OL',
#   'SPIR.OL',
#   'SNI.OL',
#   'STB.OL',
#   'STRO.OL',
#   'SUBC.OL',
#   'TECH.OL',
#   'TEKNA.OL',
#   'TEL.OL',
#   'TGS.OL',
#   'TRMED.OL',
#   'TIETO.OL',
#   'TOM.OL',
#   'TRE.OL',
#   'TRSB.OL',
#   'VEI.OL',
#   'VENDA.OL',
#   'VENDB.OL',
#   'VISTN.OL',
#   'VVL.OL',
#   'VOW.OL',
#   'VAR.OL',
#   'WAWI.OL',
#   'WSTEP.OL',
#   'WWI.OL',
#   'WWIB.OL',
#   'YAR.OL',
#   'ZAL.OL',
#   'ZAP.OL',
#   'ZLNA.OL']}

# %%
k = load_market_data(possible_markets, ticker_dictionary, start_date, end_date)
# Out:
# 2025-09-01 14:56:22.089 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 14:56:22.194
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /opt/anaconda3/envs/PortfolioOptim/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-09-01 14:56:22.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 14:56:22.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# $ASAS.OL: possibly delisted; no price data found  (1d 2021-07-01 00:00:00 -> 2025-05-28 00:00:00)
# $CMBTO.OL: possibly delisted; no price data found  (1d 2021-07-01 00:00:00 -> 2025-05-28 00:00:00) (Yahoo error = "Data doesn't exist for startDate = 1625090400, endDate = 1748383200")
# $ENH.OL: possibly delisted; no price data found  (1d 2021-07-01 00:00:00 -> 2025-05-28 00:00:00) (Yahoo error = "Data doesn't exist for startDate = 1625090400, endDate = 1748383200")
# $SNTIA.OL: possibly delisted; no price data found  (1d 2021-07-01 00:00:00 -> 2025-05-28 00:00:00) (Yahoo error = "Data doesn't exist for startDate = 1625090400, endDate = 1748383200")
# $SWON.OL: possibly delisted; no price data found  (1d 2021-07-01 00:00:00 -> 2025-05-28 00:00:00) (Yahoo error = "Data doesn't exist for startDate = 1625090400, endDate = 1748383200")
# 2025-09-01 14:56:54.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 14:56:54.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 14:56:54.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 14:56:54.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 14:56:54.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 14:56:54.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 14:56:54.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 14:56:54.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 14:56:54.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
k
# Out:
# {'Oslo Børs': [yfinance.Ticker object <2020.OL>,
#   yfinance.Ticker object <ABG.OL>,
#   yfinance.Ticker object <ABL.OL>,
#   yfinance.Ticker object <AFG.OL>,
#   yfinance.Ticker object <AGLX.OL>,
#   yfinance.Ticker object <AIRX.OL>,
#   yfinance.Ticker object <AKAST.OL>,
#   yfinance.Ticker object <AKER.OL>,
#   yfinance.Ticker object <AKBM.OL>,
#   yfinance.Ticker object <AKRBP.OL>,
#   yfinance.Ticker object <ACC.OL>,
#   yfinance.Ticker object <AKH.OL>,
#   yfinance.Ticker object <AKSO.OL>,
#   yfinance.Ticker object <AKVA.OL>,
#   yfinance.Ticker object <AMSC.OL>,
#   yfinance.Ticker object <ARCH.OL>,
#   yfinance.Ticker object <AZT.OL>,
#   yfinance.Ticker object <AFK.OL>,
#   yfinance.Ticker object <ARR.OL>,
#   yfinance.Ticker object <ATEA.OL>,
#   yfinance.Ticker object <ASA.OL>,
#   yfinance.Ticker object <AURG.OL>,
#   yfinance.Ticker object <AUSS.OL>,
#   yfinance.Ticker object <AGAS.OL>,
#   yfinance.Ticker object <ACR.OL>,
#   yfinance.Ticker object <B2I.OL>,
#   yfinance.Ticker object <BAKKA.OL>,
#   yfinance.Ticker object <BGBIO.OL>,
#   yfinance.Ticker object <BEWI.OL>,
#   yfinance.Ticker object <BNOR.OL>,
#   yfinance.Ticker object <BONHR.OL>,
#   yfinance.Ticker object <BOR.OL>,
#   yfinance.Ticker object <BRG.OL>,
#   yfinance.Ticker object <BOUV.OL>,
#   yfinance.Ticker object <BWE.OL>,
#   yfinance.Ticker object <BWLPG.OL>,
#   yfinance.Ticker object <BWO.OL>,
#   yfinance.Ticker object <BMA.OL>,
#   yfinance.Ticker object <CADLR.OL>,
#   yfinance.Ticker object <CRNA.OL>,
#   yfinance.Ticker object <CLOUD.OL>,
#   yfinance.Ticker object <CONTX.OL>,
#   yfinance.Ticker object <DNB.OL>,
#   yfinance.Ticker object <DNO.OL>,
#   yfinance.Ticker object <EIOF.OL>,
#   yfinance.Ticker object <EMGS.OL>,
#   yfinance.Ticker object <ELK.OL>,
#   yfinance.Ticker object <ELABS.OL>,
#   yfinance.Ticker object <ELMRA.OL>,
#   yfinance.Ticker object <ELO.OL>,
#   yfinance.Ticker object <ENDUR.OL>,
#   yfinance.Ticker object <ENSU.OL>,
#   yfinance.Ticker object <ENTRA.OL>,
#   yfinance.Ticker object <ENVIP.OL>,
#   yfinance.Ticker object <EQNR.OL>,
#   yfinance.Ticker object <EQVA.OL>,
#   yfinance.Ticker object <EPR.OL>,
#   yfinance.Ticker object <FLNG.OL>,
#   yfinance.Ticker object <FRO.OL>,
#   yfinance.Ticker object <GENT.OL>,
#   yfinance.Ticker object <GJF.OL>,
#   yfinance.Ticker object <GOGL.OL>,
#   yfinance.Ticker object <GOD.OL>,
#   yfinance.Ticker object <GSF.OL>,
#   yfinance.Ticker object <GYL.OL>,
#   yfinance.Ticker object <HAFNI.OL>,
#   yfinance.Ticker object <HAVI.OL>,
#   yfinance.Ticker object <HEX.OL>,
#   yfinance.Ticker object <HPUR.OL>,
#   yfinance.Ticker object <HBC.OL>,
#   yfinance.Ticker object <HYPRO.OL>,
#   yfinance.Ticker object <HSPG.OL>,
#   yfinance.Ticker object <IDEX.OL>,
#   yfinance.Ticker object <IWS.OL>,
#   yfinance.Ticker object <IOX.OL>,
#   yfinance.Ticker object <ITERA.OL>,
#   yfinance.Ticker object <JIN.OL>,
#   yfinance.Ticker object <JAREN.OL>,
#   yfinance.Ticker object <KID.OL>,
#   yfinance.Ticker object <KIT.OL>,
#   yfinance.Ticker object <KCC.OL>,
#   yfinance.Ticker object <KMCP.OL>,
#   yfinance.Ticker object <KOMPL.OL>,
#   yfinance.Ticker object <KOA.OL>,
#   yfinance.Ticker object <KOG.OL>,
#   yfinance.Ticker object <LSG.OL>,
#   yfinance.Ticker object <LIFE.OL>,
#   yfinance.Ticker object <LINK.OL>,
#   yfinance.Ticker object <MGN.OL>,
#   yfinance.Ticker object <MEDI.OL>,
#   yfinance.Ticker object <MELG.OL>,
#   yfinance.Ticker object <MOBA.OL>,
#   yfinance.Ticker object <MOWI.OL>,
#   yfinance.Ticker object <MPCC.OL>,
#   yfinance.Ticker object <MULTI.OL>,
#   yfinance.Ticker object <NAPA.OL>,
#   yfinance.Ticker object <NAVA.OL>,
#   yfinance.Ticker object <NKR.OL>,
#   yfinance.Ticker object <NEL.OL>,
#   yfinance.Ticker object <NEXT.OL>,
#   yfinance.Ticker object <NORBT.OL>,
#   yfinance.Ticker object <NOM.OL>,
#   yfinance.Ticker object <NOD.OL>,
#   yfinance.Ticker object <NHY.OL>,
#   yfinance.Ticker object <NSKOG.OL>,
#   yfinance.Ticker object <NOL.OL>,
#   yfinance.Ticker object <NAS.OL>,
#   yfinance.Ticker object <NRC.OL>,
#   yfinance.Ticker object <NYKD.OL>,
#   yfinance.Ticker object <ODL.OL>,
#   yfinance.Ticker object <ODF.OL>,
#   yfinance.Ticker object <ODFB.OL>,
#   yfinance.Ticker object <OKEA.OL>,
#   yfinance.Ticker object <OET.OL>,
#   yfinance.Ticker object <OLT.OL>,
#   yfinance.Ticker object <ORK.OL>,
#   yfinance.Ticker object <OTEC.OL>,
#   yfinance.Ticker object <OTOVO.OL>,
#   yfinance.Ticker object <PEN.OL>,
#   yfinance.Ticker object <PARB.OL>,
#   yfinance.Ticker object <PCIB.OL>,
#   yfinance.Ticker object <PSE.OL>,
#   yfinance.Ticker object <PEXIP.OL>,
#   yfinance.Ticker object <PHO.OL>,
#   yfinance.Ticker object <POL.OL>,
#   yfinance.Ticker object <PLT.OL>,
#   yfinance.Ticker object <PRS.OL>,
#   yfinance.Ticker object <PROT.OL>,
#   yfinance.Ticker object <QEC.OL>,
#   yfinance.Ticker object <RANA.OL>,
#   yfinance.Ticker object <REACH.OL>,
#   yfinance.Ticker object <RECSI.OL>,
#   yfinance.Ticker object <SDSD.OL>,
#   yfinance.Ticker object <SAGA.OL>,
#   yfinance.Ticker object <SALM.OL>,
#   yfinance.Ticker object <SALME.OL>,
#   yfinance.Ticker object <SATS.OL>,
#   yfinance.Ticker object <SCANA.OL>,
#   yfinance.Ticker object <SCATC.OL>,
#   yfinance.Ticker object <SBO.OL>,
#   yfinance.Ticker object <SHLF.OL>,
#   yfinance.Ticker object <SKUE.OL>,
#   yfinance.Ticker object <SMCRT.OL>,
#   yfinance.Ticker object <SOGN.OL>,
#   yfinance.Ticker object <SOFF.OL>,
#   yfinance.Ticker object <MING.OL>,
#   yfinance.Ticker object <SB1NO.OL>,
#   yfinance.Ticker object <MORG.OL>,
#   yfinance.Ticker object <SPOG.OL>,
#   yfinance.Ticker object <SNOR.OL>,
#   yfinance.Ticker object <SPOL.OL>,
#   yfinance.Ticker object <HELG.OL>,
#   yfinance.Ticker object <NONG.OL>,
#   yfinance.Ticker object <RING.OL>,
#   yfinance.Ticker object <SOAG.OL>,
#   yfinance.Ticker object <SPIR.OL>,
#   yfinance.Ticker object <SNI.OL>,
#   yfinance.Ticker object <STB.OL>,
#   yfinance.Ticker object <STRO.OL>,
#   yfinance.Ticker object <SUBC.OL>,
#   yfinance.Ticker object <TECH.OL>,
#   yfinance.Ticker object <TEKNA.OL>,
#   yfinance.Ticker object <TEL.OL>,
#   yfinance.Ticker object <TGS.OL>,
#   yfinance.Ticker object <TRMED.OL>,
#   yfinance.Ticker object <TIETO.OL>,
#   yfinance.Ticker object <TOM.OL>,
#   yfinance.Ticker object <TRE.OL>,
#   yfinance.Ticker object <VEI.OL>,
#   yfinance.Ticker object <VENDB.OL>,
#   yfinance.Ticker object <VISTN.OL>,
#   yfinance.Ticker object <VVL.OL>,
#   yfinance.Ticker object <VOW.OL>,
#   yfinance.Ticker object <WAWI.OL>,
#   yfinance.Ticker object <WSTEP.OL>,
#   yfinance.Ticker object <WWI.OL>,
#   yfinance.Ticker object <WWIB.OL>,
#   yfinance.Ticker object <YAR.OL>,
#   yfinance.Ticker object <ZAL.OL>,
#   yfinance.Ticker object <ZAP.OL>,
#   yfinance.Ticker object <ZLNA.OL>]}

# %%
k['Oslo Børs'][0].history()['Close'].values
# Out:
# array([125.95999146, 127.25854492, 129.85565186, 132.15310669,
#        130.6547699 , 130.05543518, 129.05654907, 129.85565186,
#        131.85343933, 135.84899902, 132.85232544, 132.65255737,
#        132.95222473, 134.94999695, 135.19999695, 137.30000305,
#        136.8999939 , 136.3999939 , 135.3999939 , 138.1000061 ,
#        135.1000061 , 132.80000305])

# %%
start_date = pd.to_datetime("2021-07-01")
end_date = pd.to_datetime("2025-05-28")

t1 = k['Oslo Børs'][0].history(auto_adjust = False, start = start_date, end = end_date).asfreq('B').ffill()['Adj Close']
t2 = k['Oslo Børs'][1].history(auto_adjust = False, start = start_date, end = end_date).asfreq('B').ffill()['Adj Close']

# %%
t2
# Out:
# Date
# 2021-07-01 00:00:00+02:00    6.699582
# 2021-07-02 00:00:00+02:00    6.646410
# 2021-07-05 00:00:00+02:00    6.646410
# 2021-07-06 00:00:00+02:00    6.699582
# 2021-07-07 00:00:00+02:00    6.659703
#                                ...
# 2025-05-21 00:00:00+02:00    6.690000
# 2025-05-22 00:00:00+02:00    6.670000
# 2025-05-23 00:00:00+02:00    6.600000
# 2025-05-26 00:00:00+02:00    6.630000
# 2025-05-27 00:00:00+02:00    6.650000
# Freq: B, Name: Adj Close, Length: 1019, dtype: float64

# %%
new_df = pd.concat([t1, t2], axis = 1)
new_df.columns = ['x', 'y']

# %%
new_df
# Out:
#                                     x         y
# Date
# 2021-07-01 00:00:00+02:00  106.102219  6.699582
# 2021-07-02 00:00:00+02:00  104.215904  6.646410
# 2021-07-05 00:00:00+02:00  104.215904  6.646410
# 2021-07-06 00:00:00+02:00  105.630623  6.699582
# 2021-07-07 00:00:00+02:00  106.102219  6.659703
# ...                               ...       ...
# 2025-05-21 00:00:00+02:00  119.610321  6.690000
# 2025-05-22 00:00:00+02:00  118.314537  6.670000
# 2025-05-23 00:00:00+02:00  117.816162  6.600000
# 2025-05-26 00:00:00+02:00  118.812912  6.630000
# 2025-05-27 00:00:00+02:00  117.716492  6.650000
#
# [1019 rows x 2 columns]

# %%
new_df.pct_change(21).dropna()+1
# Out:
#                                   x         y
# Date
# 2021-07-30 00:00:00+02:00  1.011065  0.974206
# 2021-08-02 00:00:00+02:00  1.020296  0.990000
# 2021-08-03 00:00:00+02:00  1.006692  0.994000
# 2021-08-04 00:00:00+02:00  1.006631  0.992063
# 2021-08-05 00:00:00+02:00  1.002157  1.000000
# ...                             ...       ...
# 2025-05-21 00:00:00+02:00  1.182062  1.048363
# 2025-05-22 00:00:00+02:00  1.116508  1.025817
# 2025-05-23 00:00:00+02:00  1.106604  1.010720
# 2025-05-26 00:00:00+02:00  1.067056  1.006070
# 2025-05-27 00:00:00+02:00  1.048766  1.023077
#
# [998 rows x 2 columns]
